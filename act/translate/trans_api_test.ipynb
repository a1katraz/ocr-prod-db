# %%
import os
import requests
import uuid
import json
import csv
from pathlib import Path

def make_connection(language, fromScript, toScript):
    subscription_key = '1212d7d306fb4388a534e586691d0b57'
    endpoint = 'https://api.cognitive.microsofttranslator.com'
    path = '/transliterate?api-version=3.0'
    params = '&language='+language+'&fromScript='+fromScript+'&toScript='+toScript
    constructed_url = endpoint + path + params
    
    headers = {
    'Ocp-Apim-Subscription-Key': subscription_key,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
    }
    
    return constructed_url, headers
    

def transliterate(url, headers, array):
    body_json = []
    for items in array:
        dict = {'Text':items}
        body_json.append(dict)

    request = requests.post(url, headers=headers, json=body_json)
    response = request.json()
    
    result = list() 
    for item in response:
        result.append(item['text'].title())
    
    return result

if __name__ == '__main__':
   
    url, headers = make_connection(language='hi', fromScript='deva', toScript='latn')
    #l = transliterate(url, headers, ['उत्क्रमित', 'मध्य', 'विद्यालय', 'बेलडीह', 'जलालपुर'])
    #for item in l:
    #    print(item)
    
    ac_no = '238'
    cwd = os.getcwd()
    
    all_words = list()
    dict = {}    
    
    with open(str(Path(cwd).parent.parent)+'/dict/'+ac_no+'_booth_list.csv') as file:
        csv_reader = csv.reader(file, delimiter=',')
        line = 0
        for row in csv_reader:
            if (line == 0):
                print(','.join(row))
            else:
                ac_names = (row[1]+' '+row[3].replace('_', ' ')).replace(u'\u200d', '').replace(u'\u200c', '').split(' ')
                for item in ac_names:
                    if(len(item) > 2 and item not in all_words):
                        all_words.append(item)    
            line += 1

    grps_10 = [all_words[n:n+10] for n in range(0, len(all_words), 10)]
    
    for words in grps_10:
        res = transliterate(url, headers, words)
        for i in range(0, len(res)):
            dict[words[i]] = res[i]
    
    with open(str(Path(cwd).parent.parent)+'/dict/'+ac_no+'_booth_list.csv') as file:
        csv_reader = csv.reader(file, delimiter=',')
        line = 0
        for row in csv_reader:
            if (line > 0):
                ac_eng_name = ''
                ac_parts = row[1].replace('_', ' ').replace(u'\u200d', '').replace(u'\u200c', '').split(' ')
                for part in ac_parts:
                    if(len(part) > 2):
                        ac_eng_name = ac_eng_name + ' ' + dict[part]
                ac_eng_name.strip()

                booth_eng_name = ''
                booth_parts = row[3].replace('_', ' ').replace(u'\u200d', '').replace(u'\u200c', '').split(' ')
                for part in booth_parts:
                    if(len(part) > 2):
                        booth_eng_name = booth_eng_name + ' ' + dict[part]
                booth_eng_name.strip()
                
                print(row[0] + ',' + ac_eng_name + ',' + row[2] + ',' + booth_eng_name)

            line += 1
# Out:
# Assembly_Segment_No,Assembly_Segment_Name,Booth_No,Booth_Name
# 238, Gobindapur,1, Utkramit Madhya Vidyalaya Devanpura
# 238, Gobindapur,2, Utkramit Madhya Vidyalaya Pachamba Urdu Uttari Bhag
# 238, Gobindapur,3, Utkramit Madhya Vidhalaya Pachamba Urdu Dakshini Bhag)
# 238, Gobindapur,4, Utkramit Madhya Vidyalaya Pachohiya Urdu
# 238, Gobindapur,82, Prathamik Vidyalaya Anaila
# 238, Gobindapur,83, Prathamik Vidyalaya Pratappur
# 238, Gobindapur,84, Madhya Vidyalaya Barapandeya
# 238, Gobindapur,85, Prathamik Vidyalaya Jhakhaur
# 238, Gobindapur,86, Utkramit Madhya Vidyalaya Bhatta(Poorvi Bhag)
# 238, Gobindapur,87, Utkramit Madhya Vidhalaya Bhatta (Pashchimi Bhag)
# 238, Gobindapur,88, Utkramit Madhya Vidyalaya Katahara
# 238, Gobindapur,89, Prathamik Vidyalaya Kazichak (Siur)
# 238, Gobindapur,90, Madhyamik Vidyalaya Siur Poorvi Bhag
# 238, Gobindapur,91, Madhyamik Vidyalaya Siur Pashchimi Bhag
# 238, Gobindapur,92, Madhyamik Vidhalaya Siur Dakshin Bhag
# 238, Gobindapur,93, Utkramit Madhya Vidyalaya Degma
# 238, Gobindapur,94, Utkramit Madhya Vidhalaya Badail
# 238, Gobindapur,95, Utkramit Madhya Vidyalaya Kataiya
# 238, Gobindapur,96, Prathamik Vidyalaya Duari
# 238, Gobindapur,97, Utkramit Madhya Vidyalaya Mahkar (Utari Bhag)
# 238, Gobindapur,98, Utkramit Madhya Vidyalaya Mahkar (Dakshini Bhag)
# 238, Gobindapur,99, Utkramit Madhya Vidyalaya Bhandajor Poorvi Bhag
# 238, Gobindapur,100, Utkramit Madhya Vidyalaya Bhandajor Pashchimi Bhag
# 238, Gobindapur,101, Madhya Vidyalaya Koshi Uttari Bhag
# 238, Gobindapur,102, Madhya Vidyalaya Koshi Dakshin Bhag
# 238, Gobindapur,103, Madhya Vidyayal Koshi Naya Bhawan Utari Bhag
# 238, Gobindapur,104, Utkramit Madhya Vidyalaya Godihari
# 238, Gobindapur,105, Prathamik Vidyalaya Harshitpur
# 238, Gobindapur,106, Utkramit Madhya Vidyalaya Baliari
# 238, Gobindapur,107, Utkramit Madhya Vidyalaya Rookhi Dayan Bhag
# 238, Gobindapur,108, Utkramit Madhya Vidyalaya Rukhi Bayan Bhag
# 238, Gobindapur,109, Utkramit Madhya Vidyalaya Chanaun Poorvi Bhag
# 238, Gobindapur,110, Utkramit Madhya Vidyalaya Chanaun Pashchimi Bhag
# 238, Gobindapur,111, Prathamik Vidyalaya Sadikpur
# 238, Gobindapur,112, Utkramit Madhya Vidyalaya Casmara
# 238, Gobindapur,113, Prathamik Vidyalaya Telari
# 238, Gobindapur,114, Utkramit Madhya Vidyalaya Dhanavau Poorvi Bhag
# 238, Gobindapur,115, Utkramit Madhya Vidhalaya Dhanava Pashchimi Bhag
# 238, Gobindapur,116, Anganwadi Kendra Pachagharava Ajay Nagar
# 238, Gobindapur,117, Utkramit Madhya Vidyalaya Benipur Poorvi Bhag
# 238, Gobindapur,118, Utkramit Madhya Vidyalaya Benipur Pashchimi Bhag
# 238, Gobindapur,119, Madhya Vidyalaya Rupau Poorvi Bhag
# 238, Gobindapur,199, Prathamik Vidhalaya Manasagar Patori Dakshini Bhag
# 238, Gobindapur,200, Prathamik Vidyalaya Charaul
# 238, Gobindapur,201, Utkramit Madhya Vidhalaya Pandey Gangout Utari Bhag
# 238, Gobindapur,202, Utkramit Madhya Vidhalaya Pandey Gangout Dakshini Bhag
# 238, Gobindapur,203, Utkramit Madhya Vidyalaya Chahal
# 238, Gobindapur,204, Madhya Vidhalaya Fuldih
# 238, Gobindapur,205, Prathamik Vidyalaya Farheda
# 238, Gobindapur,206, Utkramit Madhya Vidyalaya Navadih Purvi Bhag
# 238, Gobindapur,207, Utkramit Madhya Vidyalaya Navadih Pashchim Bhag
# 238, Gobindapur,208, Rajasv Kacheri Navadih Purvi Bhag
# 238, Gobindapur,209, Rajasv Kacheri Navadih Pashchimi Bhag
# 238, Gobindapur,210, Prathamik Vidyalaya Sundari
# 238, Gobindapur,211, Prathamik Vidhalaya Dhab
# 238, Gobindapur,212, Utkramit Madhya Vidyalaya Bukar Urdu Uttari Bhag
# 238, Gobindapur,213, Utkramit Madhya Vidyalaya Bukar Urdu Dakshini Bhag
# 238, Gobindapur,214, Utkramit Madhya Vidyalaya Karma
# 238, Gobindapur,215, Prathamik Vidyalaya Kevali
# 238, Gobindapur,216, Prathamik Vidyalaya Nazalli Vigaha
# 238, Gobindapur,217, Utkramit Madhya Vidyalaya Lohsinghani
# 238, Gobindapur,218, Utkramit Madhya Vidyalaya Bhaluahi Bayan Bhag
# 238, Gobindapur,219, Utkramit Madhya Vidyalaya Bhaluahi Dayan Bhag
# 238, Gobindapur,220, Utkramit Madhya Vidyalaya Vandichak
# 238, Gobindapur,221, Prathamik Vidyalaya Gadi Manjhila
# 238, Gobindapur,222, Rajakiy Madhya Vidhalaya Salaiya Utari Bhag
# 238, Gobindapur,223, Rajakiy Madhya Vidyalaya Salaiya Dakshini Bhag
# 238, Gobindapur,224, Prathamik Vidyalaya Vishnupur
# 238, Gobindapur,225, Utkramit Madhya Vidyalaya Bara Izra
# 238, Gobindapur,226, Prathamik Vidhalaya Rupi
# 238, Gobindapur,227, Prathamik Vidyalaya Mandra
# 238, Gobindapur,228, Utkramit Madhya Vidyalaya Pali Poorvi Bhag
# 238, Gobindapur,229, Utkramit Madhya Vidyalaya Pali Pashchimi Bhag
# 238, Gobindapur,230, Kanya Prathamik Vidyalaya Okhria
# 238, Gobindapur,231, Prathamik Vidyalaya Katani
# 238, Gobindapur,232, Ucch Vidyalaya Okhria
# 238, Gobindapur,233, Utkramit Madhya Vidyalaya Rustampur
# 238, Gobindapur,234, Madhya Vidyalaya Khadsari Poorvi Bhag
# 238, Gobindapur,235, Madhya Vidyalaya Khadsari Pashchimi Bhag
# 238, Gobindapur,236, Utkramit Madhya Vidyalaya Carmatod Poorvi Bhag
# 238, Gobindapur,237, Utkramit Madhya Vidhalaya Carmatod Pashchimi Bhag
# 238, Gobindapur,238, Prathamik Vidyalaya Kadahar
# 238, Gobindapur,239, Madhya Vidyalaya Badarajeepoorvi Bhag
# 238, Gobindapur,240, Madhya Vidhalaya Badraji Pashchimi Bhag
# 238, Gobindapur,241, Utkramit Madhya Vidyalaya Kutubchak
# 238, Gobindapur,242, Madhya Vidyalaya Khaira
# 238, Gobindapur,243, Utkramit Madhya Vidyalaya Chhabail Poorvi Bhag
# 238, Gobindapur,244, Utkramit Madhya Vidhalaya Chhabail Pashchimi Bhag
# 238, Gobindapur,245, Prathamik Vidyalaya Bhandari
# 238, Gobindapur,246, Prathamik Vidyalaya Mahapur Banya Bhag
# 238, Gobindapur,247, Prathamik Vidyalaya Mahapur Dayan Bhag
# 238, Gobindapur,248, Madhya Vidyalaya Darawau Uttari Bhag
# 238, Gobindapur,249, Madhya Vidyalaya Darawau Madhya Bhag
# 238, Gobindapur,250, Madhya Vidhalaya Daravan Dakshini Bhag
# 238, Gobindapur,251, Utkramit Madhya Vidyalaya Afradih
# 238, Gobindapur,252, Rajakiy Buniadi Madhya Vidyalaya Baroun Bazitpur
# 238, Gobindapur,253, Utkramit Madhya Vidyalaya Bhualtand
# 238, Gobindapur,254, Prathamik Vidyalaya Doman Bag
# 238, Gobindapur,255, Prathamik Vidyalaya Radhava
# 238, Gobindapur,256, Utkramit Madhya Vidhalaya Sarauni Utari Bhag
# 238, Gobindapur,257, Utkramit Madhya Vidyalaya Sarauni Dakshini Bhag
# 238, Gobindapur,258, Madhya Vidyalaya Kouakol Uttari Bhag
# 238, Gobindapur,259, Madhya Vidhalaya Kouakol Dakshini Bhag
# 238, Gobindapur,260, Madhya Vidyalaya Kouakol Pashchimi Bhag
# 238, Gobindapur,261, Utkramit Madhya Vidyalaya Bhormavag Uttari Bhag
# 238, Gobindapur,262, Utkramit Madhya Vidyalaya Bhormavag Dakshini Bhag
# 238, Gobindapur,263, Prathamik Vidyalaya Itapakava Poorvi Bhag
# 238, Gobindapur,264, Prathamik Vidhalaya Itapacaba Pashchimi Bhag
# 238, Gobindapur,265, Utkramit Madhya Vidyalaya Kolhuabar
# 238, Gobindapur,266, Utkramit Madhya Vidyalaya Baluarampur Poorv Bhag
# 238, Gobindapur,267, Utkramit Madhya Vidhalaya Balua Rampur Pashchimi Bhag
# 238, Gobindapur,268, Utkramit Madhya Vidyalaya Gudighat
# 238, Gobindapur,269, Utkramit Madhya Vidyalaya Bandaili Khurd
# 238, Gobindapur,270, Utkramit Madhya Vidyalaya Chongwa Panasgava Poorv Bhag
# 238, Gobindapur,271, Utkramit Madhya Vidhalaya Chongwa Panasgava Pashchimi Bhag
# 238, Gobindapur,272, Utkramit Madhya Vidyalaya Joravaradih
# 238, Gobindapur,273, Prathamik Vidyalaya Turiadih
# 238, Gobindapur,274, Utkramit Madhya Vidyalaya Sokhodevara Utari Bhag
# 238, Gobindapur,275, Utkramit Madhya Vidhalaya Sokhodevara Dakshini Bhag
# 238, Gobindapur,276, Navasrijit Prathamik Vidyalaya Vidla Mode Poorvi Bhag
# 238, Gobindapur,277, Navasrijit Prathamik Vidyalaya Vidla Mode (Pashchimi Bhag)
# 238, Gobindapur,278, Utkramit Madhya Vidyalaya Pachamba
# 238, Gobindapur,279, Utkramit Madhya Vidyalaya Pavapuri Govaraiya
# 238, Gobindapur,280, Prathamik Vidyalaya Durga Mandap
# 238, Gobindapur,281, Rajasv Kacheri Kouakaul Dakshini Bhag
# 238, Gobindapur,282, Rajasv Kacheri Kouakol Utari Bhag
# 238, Gobindapur,283, Utkramit Madhya Vidyalaya Taroun Poorvi Bhag
# 238, Gobindapur,284, Utkramit Madhya Vidyalaya Taroun Pashchimi Bhag
# 238, Gobindapur,285, Lohiya Bhawan Prakhand Parisar Kouakol
# 238, Gobindapur,286, Prathamik Vidhalaya Bariarpur
# 238, Gobindapur,287, Utkramit Madhya Vidyalaya Bijho Poorvi Bhag
# 238, Gobindapur,288, Utkramit Madhya Vidhalaya Vijho Pashchimi Bhag
# 238, Gobindapur,289, Utkramit Madhya Vidyalaya Pahadpur Uttari Bhag
# 238, Gobindapur,290, Utkramit Madhya Vidyalaya Pahadpur Dakshini Bhag
# 238, Gobindapur,291, Prathamik Vidyalaya Mananiyatari
# 238, Gobindapur,292, Utkramit Madhya Vidyalaya Tikodih
# 238, Gobindapur,293, Madhya Vidhalaya Dhamani Utari Bhag
# 238, Gobindapur,294, Madhya Vidhalaya Dhamani Dakshini Bhag
# 238, Gobindapur,295, Utkramit Madhya Vidhalaya Madhurapur Poorvi Behag
# 238, Gobindapur,296, Utkramit Madhya Vidyalaya Madhurapur Pashchimi Bhag
# 238, Gobindapur,297, Panchayat Bhawan Madhurapur Bayan Bhag
# 238, Gobindapur,298, Panchayat Bhawan Madhurapur Daya Bhag
# 238, Gobindapur,299, Utkramit Madhya Vidyalaya Bhavarkol Utari Bhag
# 238, Gobindapur,300, Utkramit Madhya Vidyalaya Bhavarkol Dakshani Bhag
# 238, Gobindapur,301, Utkramit Madhya Vidhalaya Guadhodhara Poorvi Bhag
# 238, Gobindapur,302, Utkramit Madhya Vidyalaya Guaghoghara Pashchimi Bhag
# 238, Gobindapur,303, Utkramit Madhya Vidyalaya Lalpur Purvi Bhag
# 238, Gobindapur,304, Utkramit Madhya Vidyalaya Lalpur Pashchimi Bhag
# 238, Gobindapur,305, Utkramit Madhya Vidyalaya Mannapur
# 238, Gobindapur,306, Prathamik Vidhalaya Jhilar
# 238, Gobindapur,307, Utkramit Madhya Vidyalaya Mahudar Purvi Bhag
# 238, Gobindapur,308, Utkramit Madhya Vidyalaya Mahudar Pashchimi Bhag
# 238, Gobindapur,309, Utkramit Madhya Vidhalaya Mahuliyatod Utari Bhag
# 238, Gobindapur,310, Utkramit Madhya Vidyalaya Mahuliyatod Dakshini Bhag
# 238, Gobindapur,311, Prathamik Vidyalaya Danian
