# %%
import os
from pathlib import Path
import PyPDF2
import sys
import re

def break_line(line):
    rows = list()
    items = re.split(r'(\d+)', line.strip())
    pc_no = items[1]
    pc_name = items[2][1:].strip()
    if('(' in pc_name):
        pc_classification = pc_name[pc_name.find('(')+1:pc_name.find(')')]
        pc_name = pc_name[0:pc_name.find('(')-1]
    else:
        pc_classification = 'General'
    
    for index in range(3, len(items)-1, 2):
        ac_no = items[index]
        index += 1
        ac_name = items[index][1:].replace('&', '').replace(' and ', '').replace(',', '').replace('.', '').strip()
        if('(' in ac_name):
            ac_classification = ac_name[ac_name.find('(')+1:ac_name.find(')')]
            ac_name = ac_name[0:ac_name.find('(')-1]
        else:
            ac_classification = 'General'
        
        row = pc_no + ',' + pc_name + ',' + pc_classification + ',' \
                + ac_no + ',' + ac_name + ',' + ac_classification
        rows.append(row)
        
    return rows

if __name__ == '__main__':
    
    #Give me delimited file from ECI in the format as Bihar_Delimitation.pdf
    #Spits out mapping of AC to PC and PC and AC Names in English
    
    cwd = os.getcwd()
    #name = sys.argv[1]
    name = 'Bihar'
    filepath = str(Path(cwd).parent.parent)+'/docs/delims/'+name+'_delimitation.pdf'
    
    pdf = PyPDF2.PdfFileReader(open(filepath, 'rb'))
    pages = pdf.numPages
    
    all_words = list()
    
    for i in range(0, pages):
        page = pdf.getPage(i)
        words = page.extractText().split(' ')
        all_words.extend(words)
    
    line = ''
    lines = list()
    
    for word in all_words:
        if(re.match(r'^\d+\.$', word)):
            lines.append(line)
            line = word.strip()
        elif(word.isdigit()): #is only page number, skip
            continue
        elif('NOTE' in word): #signifies end of usable data
            lines.append(line)
            break
        else:
            line += word.strip() + ' '
    
    all_rows = list() 
    
    for line in lines:
        if(re.match(r'^\d+\.', line)):
            line = re.sub(' +', ' ', line).replace('\t', '').replace('\r', '').replace('\n', '')
            #print('Line:' + line)
            rows = break_line(line)
            all_rows.extend(rows)
        else:       #useless line, skip
            continue
    
    print('pc_no, pc_name, pc_classification, ac_no, ac_name, ac_classification')
    for row in all_rows:
        print (row)
# Out:
# pc_no, pc_name, pc_classification, ac_no, ac_name, ac_classification
# 1,Valmiki Nagar,General,1,Valmiki Nagar,General
# 1,Valmiki Nagar,General,2,Ramnagar,SC
# 1,Valmiki Nagar,General,3,Narkatiaganj,General
# 1,Valmiki Nagar,General,4,Bagaha,General
# 1,Valmiki Nagar,General,5,Lauriya,General
# 1,Valmiki Nagar,General,9,Sikta,General
# 2,Paschim Champaran,General,6,Nautan,General
# 2,Paschim Champaran,General,7,Chanpatia,General
# 2,Paschim Champaran,General,8,Bettiah,General
# 2,Paschim Champaran,General,10,Raxaul,General
# 2,Paschim Champaran,General,11,Sugauli,General
# 2,Paschim Champaran,General,12,Narkatia,General
# 3,Purvi Champaran,General,13,Harsidhi,SC
# 3,Purvi Champaran,General,14,Govindganj,General
# 3,Purvi Champaran,General,15,Kesaria,General
# 3,Purvi Champaran,General,16,Kalyanpur,General
# 3,Purvi Champaran,General,17,Pipra,General
# 3,Purvi Champaran,General,19,Motihari,General
# 4,Sheohar,General,18,Madhuban,General
# 4,Sheohar,General,20,Chiraia,General
# 4,Sheohar,General,21,Dhaka,General
# 4,Sheohar,General,22,Sheohar,General
# 4,Sheohar,General,23,Riga,General
# 4,Sheohar,General,30,Belsand,General
# 5,Sitamarhi,General,24,Bathnah,SC
# 5,Sitamarhi,General,25,Parihar,General
# 5,Sitamarhi,General,26,Sursand,General
# 5,Sitamarhi,General,27,Bajpatti,General
# 5,Sitamarhi,General,28,Sitamarhi,General
# 5,Sitamarhi,General,29,Runnisaidpur,General
# 6,Madhubani,General,31,Harlakhi,General
# 6,Madhubani,General,32,Benipatti,General
# 6,Madhubani,General,35,Bisfi,General
# 6,Madhubani,General,36,Madhubani,General
# 6,Madhubani,General,86,Keoti,General
# 6,Madhubani,General,87,Jale,General
# 7,Jhanjharpur,General,33,Khajauli,General
# 7,Jhanjharpur,General,34,Babubarhi,General
# 7,Jhanjharpur,General,37,Rajnagar,SC
# 7,Jhanjharpur,General,38,Jhanjharpur,General
# 7,Jhanjharpur,General,39,Phulparas,General
# 7,Jhanjharpur,General,40,Laukaha,General
# 8,Supaul,General,41,Nirmali,General
# 8,Supaul,General,42,Pipra,General
# 8,Supaul,General,43,Supaul,General
# 8,Supaul,General,44,Triveniganj,SC
# 8,Supaul,General,45,Chhatapur,General
# 8,Supaul,General,72,Singheshwar,SC
# 9,Araria,General,46,Narpatganj,General
# 9,Araria,General,47,Raniganj,SC
# 9,Araria,General,48,Forbesganj,General
# 9,Araria,General,49,Araria,General
# 9,Araria,General,50,Jokhihat,General
# 9,Araria,General,51,Sikti,General
# 10,Kishanganj,General,52,Bahadurganj,General
# 10,Kishanganj,General,53,Thakurganj,General
# 10,Kishanganj,General,54,Kishanganj,General
# 10,Kishanganj,General,55,Kochadhaman,General
# 10,Kishanganj,General,56,Amour,General
# 10,Kishanganj,General,57,Baisi,General
# 11,Katihar,General,63,Katihar,General
# 11,Katihar,General,64,Kadwa,General
# 11,Katihar,General,65,Balrampur,General
# 11,Katihar,General,66,Pranpur,General
# 11,Katihar,General,67,Manihari,ST
# 11,Katihar,General,68,Barari,General
# 12,Purnia,General,58,Kasba,General
# 12,Purnia,General,59,Banmankhi,SC
# 12,Purnia,General,60,Rupauli,General
# 12,Purnia,General,61,Dhamdaha,General
# 12,Purnia,General,62,Purnia,General
# 12,Purnia,General,69,Korha,SC
# 13,Madhepura,General,70,Alamnagar,General
# 13,Madhepura,General,71,Bihariganj,General
# 13,Madhepura,General,73,Madhepura,General
# 13,Madhepura,General,74,Sonbarsha,SC
# 13,Madhepura,General,75,Saharsa,General
# 13,Madhepura,General,77,Mahishi,General
# 14,Darbhanga,General,79,Gaura Bauram,General
# 14,Darbhanga,General,80,Benipur,General
# 14,Darbhanga,General,81,Alinagar,General
# 14,Darbhanga,General,82,Darbhanga Rural,General
# 14,Darbhanga,General,83,Darbhanga,General
# 14,Darbhanga,General,85,Bahadurpur,General
# 15,Muzaffarpur,General,88,Gaighat,General
# 15,Muzaffarpur,General,89,Aurai,General
# 15,Muzaffarpur,General,91,Bochahan,SC
# 15,Muzaffarpur,General,92,Sakra,SC
# 15,Muzaffarpur,General,93,Kurhani,General
# 15,Muzaffarpur,General,94,Muzaffarpur,General
# 16,Vaishali,General,90,Minapur,General
# 16,Vaishali,General,95,Kanti,General
# 16,Vaishali,General,96,Baruraj,General
# 16,Vaishali,General,97,Paroo,General
# 16,Vaishali,General,98,Sahebganj,General
# 16,Vaishali,General,125,Vaishali,General
# 17,Gopalganj,SC,99,Baikunthpur,General
# 17,Gopalganj,SC,100,Barauli,General
# 17,Gopalganj,SC,101,Gopalganj,General
# 17,Gopalganj,SC,102,Kuchaikote,General
# 17,Gopalganj,SC,103,Bhore,SC
# 17,Gopalganj,SC,104,Hathua,General
# 18,Siwan,General,105,Siwan,General
# 18,Siwan,General,106,Ziradei,General
# 18,Siwan,General,107,Darauli,SC
# 18,Siwan,General,108,Raghunathpur,General
# 18,Siwan,General,109,Daraunda,General
# 18,Siwan,General,110,Barharia,General
# 19,Maharajganj,General,111,Goriyakothi,General
# 19,Maharajganj,General,112,Maharajganj,General
# 19,Maharajganj,General,113,Ekma,General
# 19,Maharajganj,General,114,Manjhi,General
# 19,Maharajganj,General,115,Baniapur,General
# 19,Maharajganj,General,116,Taraiya,General
# 20,Saran,General,117,Marhaura,General
# 20,Saran,General,118,Chapra,General
# 20,Saran,General,119,Garkha,SC
# 20,Saran,General,120,Amnour,General
# 20,Saran,General,121,Parsa,General
# 20,Saran,General,122,Sonepur,General
# 21,Hajipur,SC,123,Hajipur,General
# 21,Hajipur,SC,124,Lalganj,General
# 21,Hajipur,SC,126,Mahua,General
# 21,Hajipur,SC,127,Raja Pakar,SC
# 21,Hajipur,SC,128,Raghopur,General
# 21,Hajipur,SC,129,Mahnar,General
# 22,Ujiarpur,General,130,Patepur,SC
# 22,Ujiarpur,General,134,Ujiarpur,General
# 22,Ujiarpur,General,135,Morwa,General
# 22,Ujiarpur,General,136,Sarairanjan,General
# 22,Ujiarpur,General,137,Mohiuddinnagar,General
# 22,Ujiarpur,General,138,Bibhutipur,General
# 23,Samastipur,SC,78,Kusheshwar Asthan,SC
# 23,Samastipur,SC,84,Hayaghat,General
# 23,Samastipur,SC,131,Kalyanpur,SC
# 23,Samastipur,SC,132,Warisnagar,General
# 23,Samastipur,SC,133,Samastipur,General
# 23,Samastipur,SC,139,Rosera,SC
# 24,Begusarai,General,141,Cheria Bariarpur,General
# 24,Begusarai,General,142,Bachhwara,General
# 24,Begusarai,General,143,Teghra,General
# 24,Begusarai,General,144,Matihani,General
# 24,Begusarai,General,145,Sahebpur Kamal,General
# 24,Begusarai,General,146,Begusarai,General
# 24,Begusarai,General,147,Bakhri,SC
# 25,Khagaria,General,76,Simri Bakhtiarpur,General
# 25,Khagaria,General,140,Hasanpur,General
# 25,Khagaria,General,148,Alauli,SC
# 25,Khagaria,General,149,Khagaria,General
# 25,Khagaria,General,150,Beldaur,General
# 25,Khagaria,General,151,Parbatta,General
# 26,Bhagalpur,General,152,Bihpur,General
# 26,Bhagalpur,General,153,Gopalpur,General
# 26,Bhagalpur,General,154,Pirpainti,SC
# 26,Bhagalpur,General,155,Kahalgaon,General
# 26,Bhagalpur,General,156,Bhagalpur,General
# 26,Bhagalpur,General,158,Nathnagar,General
# 27,Banka,General,157,Sultanganj,General
# 27,Banka,General,159,Amarpur,General
# 27,Banka,General,160,Dhoraiya,SC
# 27,Banka,General,161,Banka,General
# 27,Banka,General,162,Katoria,ST
# 27,Banka,General,163,Belhar,General
# 28,Munger,General,165,Munger,General
# 28,Munger,General,166,Jamalpur,General
# 28,Munger,General,167,Suryagarha,General
# 28,Munger,General,168,Lakhisarai,General
# 28,Munger,General,178,Mokama,General
# 28,Munger,General,179,Barh,General
# 29,Nalanda,General,171,Asthawan,General
# 29,Nalanda,General,172,Biharsharif,General
# 29,Nalanda,General,173,Rajgir,SC
# 29,Nalanda,General,174,Islampur,General
# 29,Nalanda,General,175,Hilsa,General
# 29,Nalanda,General,176,Nalanda,General
# 29,Nalanda,General,177,Harnaut,General
# 30,Patna Sahib,General,180,Bakhtiarpur,General
# 30,Patna Sahib,General,181,Digha,General
# 30,Patna Sahib,General,182,Bankipur,General
# 30,Patna Sahib,General,183,Kumhrar,General
# 30,Patna Sahib,General,184,Patna Sahib,General
# 30,Patna Sahib,General,185,Fatuha,General
# 31,Pataliputra,General,186,Danapur,General
# 31,Pataliputra,General,187,Maner,General
# 31,Pataliputra,General,188,Phulwari,SC
# 31,Pataliputra,General,189,Masaurhi,SC
# 31,Pataliputra,General,190,Paliganj,General
# 31,Pataliputra,General,191,Bikram,General
# 32,Arrah,General,192,Sandesh,General
# 32,Arrah,General,193,Barhara,General
# 32,Arrah,General,194,Arrah,General
# 32,Arrah,General,195,Agiaon,SC
# 32,Arrah,General,196,Tarari,General
# 32,Arrah,General,197,Jagdishpur,General
# 32,Arrah,General,198,Shahpur,General
# 33,Buxar,General,199,Brahampur,General
# 33,Buxar,General,200,Buxar,General
# 33,Buxar,General,201,Dumraon,General
# 33,Buxar,General,202,Rajpur,SC
# 33,Buxar,General,203,Ramgarh,General
# 33,Buxar,General,210,Dinara,General
# 34,Sasaram,SC,204,Mohania,SC
# 34,Sasaram,SC,205,Bhabua,General
# 34,Sasaram,SC,206,Chainpur,General
# 34,Sasaram,SC,207,Chenari,SC
# 34,Sasaram,SC,208,Sasaram,General
# 34,Sasaram,SC,209,Kargahar,General
# 35,Karakat,General,211,Nokha,General
# 35,Karakat,General,212,Dehri,General
# 35,Karakat,General,213,Karakat,General
# 35,Karakat,General,219,Goh,General
# 35,Karakat,General,220,Obra,General
# 35,Karakat,General,221,Nabinagar,General
# 36,Jahanabad,General,214,Arwal,General
# 36,Jahanabad,General,215,Kurtha,General
# 36,Jahanabad,General,216,Jahanabad,General
# 36,Jahanabad,General,217,Ghosi,General
# 36,Jahanabad,General,218,Makhdumpur,SC
# 36,Jahanabad,General,233,Atri,General
# 37,Aurangabad,General,222,Kutumba,SC
# 37,Aurangabad,General,223,Aurangabad,General
# 37,Aurangabad,General,224,Rafiganj,General
# 37,Aurangabad,General,225,Gurua,General
# 37,Aurangabad,General,227,Imamganj,SC
# 37,Aurangabad,General,231,Tikari,General
# 38,Gaya,SC,226,Sherghati,General
# 38,Gaya,SC,228,Barachatti,SC
# 38,Gaya,SC,229,Bodh Gaya,SC
# 38,Gaya,SC,230,Gaya Town,General
# 38,Gaya,SC,232,Belaganj,General
# 38,Gaya,SC,234,Wazirganj,General
# 39,Nawada,General,170,Barbigha,General
# 39,Nawada,General,235,Rajauli,SC
# 39,Nawada,General,236,Hisua,General
# 39,Nawada,General,237,Nawada,General
# 39,Nawada,General,238,Gobindpur,General
# 39,Nawada,General,239,Warsaliganj,General
# 40,Jamui,SC,164,Tarapur,General
# 40,Jamui,SC,169,Sheikhpura,General
# 40,Jamui,SC,240,Sikandra,SC
# 40,Jamui,SC,241,Jamui,General
# 40,Jamui,SC,242,Jhajha,General
# 40,Jamui,SC,243,Chakai,General
